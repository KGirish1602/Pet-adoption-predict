# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('pet_adoption_data.csv')

# %%
data.head()
# Out:
#    PetID PetType             Breed  AgeMonths  Color    Size   WeightKg  \
# 0    500    Bird          Parakeet        103  Black   Large  16.357608
# 1    501  Rabbit          Labrador          8  Black  Medium  12.625582
# 2    502     Dog          Parakeet        153   Gray   Small   9.624407
# 3    503    Bird  Golden Retriever         91   Gray  Medium  20.770021
# 4    504    Bird  Golden Retriever        174   Gray  Medium   7.025923
#
#    Vaccinated  HealthCondition  TimeInShelterDays  AdoptionFee  PreviousOwner  \
# 0           1                0                 43          335              0
# 1           0                0                 50           93              0
# 2           0                0                  3           79              0
# 3           0                0                 59           37              1
# 4           1                0                 28          407              0
#
#    AdoptionLikelihood
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2007 entries, 0 to 2006
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PetID               2007 non-null   int64
#  1   PetType             2007 non-null   object
#  2   Breed               2007 non-null   object
#  3   AgeMonths           2007 non-null   int64
#  4   Color               2007 non-null   object
#  5   Size                2007 non-null   object
#  6   WeightKg            2007 non-null   float64
#  7   Vaccinated          2007 non-null   int64
#  8   HealthCondition     2007 non-null   int64
#  9   TimeInShelterDays   2007 non-null   int64
#  10  AdoptionFee         2007 non-null   int64
#  11  PreviousOwner       2007 non-null   int64
#  12  AdoptionLikelihood  2007 non-null   int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 204.0+ KB

# %%
df = data.drop(['PetID'],axis=1)

# %%
df = pd.get_dummies(df,dtype=int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2007 entries, 0 to 2006
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   AgeMonths               2007 non-null   int64
#  1   WeightKg                2007 non-null   float64
#  2   Vaccinated              2007 non-null   int64
#  3   HealthCondition         2007 non-null   int64
#  4   TimeInShelterDays       2007 non-null   int64
#  5   AdoptionFee             2007 non-null   int64
#  6   PreviousOwner           2007 non-null   int64
#  7   AdoptionLikelihood      2007 non-null   int64
#  8   PetType_Bird            2007 non-null   int32
#  9   PetType_Cat             2007 non-null   int32
#  10  PetType_Dog             2007 non-null   int32
#  11  PetType_Rabbit          2007 non-null   int32
#  12  Breed_Golden Retriever  2007 non-null   int32
#  13  Breed_Labrador          2007 non-null   int32
#  14  Breed_Parakeet          2007 non-null   int32
#  15  Breed_Persian           2007 non-null   int32
#  16  Breed_Poodle            2007 non-null   int32
#  17  Breed_Siamese           2007 non-null   int32
#  18  Color_Black             2007 non-null   int32
#  19  Color_Brown             2007 non-null   int32
#  20  Color_Gray              2007 non-null   int32
#  21  Color_Orange            2007 non-null   int32
#  22  Color_White             2007 non-null   int32
#  23  Size_Large              2007 non-null   int32
#  24  Size_Medium             2007 non-null   int32
#  25  Size_Small              2007 non-null   int32
# dtypes: float64(1), int32(18), int64(7)
# memory usage: 266.7 KB

# %%
df.corr()['AdoptionLikelihood'].sort_values()[:-1]
# Out:
# Size_Large               -0.264350
# HealthCondition          -0.257221
# Size_Small               -0.205686
# AgeMonths                -0.140753
# Breed_Siamese            -0.089423
# Breed_Persian            -0.079252
# Breed_Parakeet           -0.056798
# Breed_Poodle             -0.045603
# Breed_Golden Retriever   -0.044097
# PreviousOwner            -0.032885
# AdoptionFee              -0.032725
# PetType_Bird             -0.031289
# Color_Gray               -0.029771
# Color_Orange             -0.020107
# WeightKg                 -0.010912
# PetType_Rabbit           -0.006025
# PetType_Dog              -0.003872
# Color_White               0.002188
# TimeInShelterDays         0.017154
# Color_Black               0.022766
# Color_Brown               0.025258
# PetType_Cat               0.041247
# Vaccinated                0.298957
# Breed_Labrador            0.315187
# Size_Medium               0.464121
# Name: AdoptionLikelihood, dtype: float64

# %%
X = df.drop(['AdoptionLikelihood'],axis=1)

# %%
y = df['AdoptionLikelihood']

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfcModel = RandomForestClassifier()

# %%
rfcModel.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict = rfcModel.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       429
#            1       0.95      0.89      0.92       234
#
#     accuracy                           0.95       663
#    macro avg       0.95      0.93      0.94       663
# weighted avg       0.95      0.95      0.95       663

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[419,  10],
#        [ 26, 208]], dtype=int64)
